# %%
import pandas as pd
from datetime import datetime

# %%
# Load event data
merged_event_jan = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_jan.csv',delimiter=',')
merged_event_feb = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_feb.csv',delimiter=',')
merged_event_mar = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_mar.csv',delimiter=',')
merged_event_apr = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_apr.csv',delimiter=',')
merged_event_may = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_may.csv',delimiter=',')
merged_event_jun = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_jun.csv',delimiter=',')
merged_event_jul = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_jul.csv',delimiter=',')
merged_event_aug = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_aug.csv',delimiter=',')
merged_event_sep = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_sep.csv',delimiter=',')
merged_event_oct = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_oct.csv',delimiter=',')
merged_event_nov = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_nov.csv',delimiter=',')
merged_event_dec = pd.read_csv('/Users/tianying/Documents/Statistics and Data Science/Course/Modern Data Analytics/MDA project/MDA-Georgia/Preprocessing/merged_event_dec.csv',delimiter=',')

# %%
# Concatenate event data
dfs = [merged_event_jan,merged_event_feb,merged_event_mar,merged_event_apr,merged_event_may,merged_event_jun,merged_event_jul,merged_event_aug,merged_event_sep,merged_event_oct,merged_event_nov,merged_event_dec]
combined_noise_event = pd.concat(dfs, ignore_index=True)

combined_noise_event.head(10000000)
# Out:
#                         description         result_timestamp  \
# 0      MP 03: Naamsestraat 62 Taste  2022-01-01 00:01:31.362
# 1      MP 03: Naamsestraat 62 Taste  2022-01-01 00:02:19.368
# 2      MP 03: Naamsestraat 62 Taste  2022-01-01 00:02:23.368
# 3      MP 03: Naamsestraat 62 Taste  2022-01-01 00:02:33.370
# 4      MP 03: Naamsestraat 62 Taste  2022-01-01 00:02:57.373
# ...                             ...                      ...
# 81051            MP08bis - Vrijthof  2022-12-29 09:08:11.171
# 81052            MP08bis - Vrijthof  2022-12-30 13:54:27.224
# 81053            MP08bis - Vrijthof  2022-12-30 13:56:57.225
# 81054            MP08bis - Vrijthof  2022-12-30 15:09:33.233
# 81055            MP08bis - Vrijthof  2022-12-31 12:01:26.480
#
#        noise_event_laeq_primary_detected_certainty  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# ...

# %%
combined_noise_event.to_csv('combined_noise_event.csv', index=False)
